# %%
import numpy as np
import scipy
import scipy.io
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from scipy.ndimage import gaussian_filter

# %%
def plot_csd_heatmap(csd_data, layer):
    # Load the CSD data from the provided file
    mat_data = scipy.io.loadmat(csd_data)
    source_tcs = mat_data['source_tcs']
    data = source_tcs

    # Define layer names
    layer_names = ['Layer 1', 'Layer 2', 'Layer 3', 'Layer 4', 'Layer 5', 'Layer 6', 'Layer 7', 'Layer 8', 'Layer 9', 'Layer 10', 'Layer 11']

    # Compute the CSD
    csd = np.gradient(data, axis=0)

    # Create a time axis
    time = np.arange(data.shape[1])

    # Create a depth axis
    depth = np.arange(data.shape[0])

    # Create a grid for plotting
    time_grid, depth_grid = np.meshgrid(time, depth)

    # Plot the CSD as a heatmap
    plt.figure(figsize=(8, 4))
    plt.imshow(csd, cmap="RdBu_r", aspect='auto', extent=[time[0], time[-1], depth[0], depth[-1]])
    plt.colorbar(label='Current Source Density')
    plt.xlabel('Time')
    plt.ylabel('Layer')
    plt.yticks(depth, layer_names)  # Set y-axis tick labels
    plt.title('CSD of source at index 5 layer '+ str(layer))
    plt.show()

# %% [markdown]
# #### Layer 3

# %%
csd_data3 = '/home/smaiti/Danc_lab/Final_Experiments/csd_processing_files/sim@index_5_layer_3to9/sim@index_5_layer_3.mat'
plot_csd_heatmap(csd_data3, 3)

# %%
csd_data3
mat_data3 = scipy.io.loadmat(csd_data3)
mat_data3
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri Jun 30 12:35:16 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'source_tcs': array([[ 4.64738224e-06,  1.32026983e-06, -5.62431004e-06, ...,
#           6.94855349e-06,  1.06685554e-05, -1.49744423e-07],
#         [-8.47142142e-07,  3.09013209e-06, -2.69542236e-06, ...,
#           1.03030419e-05,  5.85288755e-06, -1.53309771e-06],
#         [ 5.57742100e-06,  2.40705982e-06, -4.01530462e-06, ...,
#           1.06057925e-05,  1.40501673e-05, -5.07410854e-07],
#         ...,
#         [-8.71353206e-06,  3.58795283e-06, -5.36224669e-06, ...,
#           7.93362923e-06,  2.86343665e-07, -3.58337546e-06],
#         [-1.18451202e-06,  5.39010125e-07, -8.01494117e-07, ...,
#           1.05919108e-06,  4.83341323e-07, -5.52005740e-07],
#         [ 6.27107035e-06, -1.57575118e-06, -4.64235663e-06, ...,
#          -7.70470009e-07,  9.50107883e-06,  5.74569173e-07]])}

# %%
csd_data9
mat_data9 = scipy.io.loadmat(csd_data9)
mat_data9
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri Jun 30 12:42:01 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'source_tcs': array([[ 9.55179766e-06, -4.23336451e-06,  9.31385173e-07, ...,
#          -4.11603169e-06, -1.00957081e-06, -4.54554013e-06],
#         [ 6.17328946e-06, -5.02737383e-07,  4.69299596e-06, ...,
#          -5.04531078e-06,  5.93549195e-07, -1.40804205e-06],
#         [ 7.79796615e-06, -7.09601943e-06,  2.21150252e-06, ...,
#          -4.92546568e-06, -9.71893540e-07, -4.49256310e-06],
#         ...,
#         [ 1.29810806e-05,  1.04148778e-05,  6.28935192e-06, ...,
#          -7.17097238e-06, -8.44440540e-07,  1.65269521e-06],
#         [ 2.09564170e-06,  1.52892362e-06,  8.92872264e-07, ...,
#          -1.13344092e-06, -2.17548608e-07,  3.38902530e-07],
#         [ 5.34095248e-06, -6.55588456e-06, -5.43701936e-06, ...,
#           7.95976038e-07, -5.04341837e-06, -5.91034697e-06]])}

# %%
csd_data9 = '/home/smaiti/Danc_lab/Final_Experiments/csd_processing_files/sim@index_5_layer_3to9/sim@index_5_layer_9.mat'
plot_csd_heatmap(csd_data9, 9)

# %%
mat_data9
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri Jun 30 12:42:01 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'source_tcs': array([[ 9.55179766e-06, -4.23336451e-06,  9.31385173e-07, ...,
#          -4.11603169e-06, -1.00957081e-06, -4.54554013e-06],
#         [ 6.17328946e-06, -5.02737383e-07,  4.69299596e-06, ...,
#          -5.04531078e-06,  5.93549195e-07, -1.40804205e-06],
#         [ 7.79796615e-06, -7.09601943e-06,  2.21150252e-06, ...,
#          -4.92546568e-06, -9.71893540e-07, -4.49256310e-06],
#         ...,
#         [ 1.29810806e-05,  1.04148778e-05,  6.28935192e-06, ...,
#          -7.17097238e-06, -8.44440540e-07,  1.65269521e-06],
#         [ 2.09564170e-06,  1.52892362e-06,  8.92872264e-07, ...,
#          -1.13344092e-06, -2.17548608e-07,  3.38902530e-07],
#         [ 5.34095248e-06, -6.55588456e-06, -5.43701936e-06, ...,
#           7.95976038e-07, -5.04341837e-06, -5.91034697e-06]])}

# %%
source_tcs = mat_data9['source_tcs']  # Extract the source_tcs data

# %%
# Plotting the signal
plt.figure()
plt.plot(source_tcs.T)  # Transpose the data to plot each column as a separate line
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Signal Plot')
plt.show()

# %%
source_tcs3 = mat_data3['source_tcs']
# Plotting the signal
plt.figure()
plt.plot(source_tcs3.T)  # Transpose the data to plot each column as a separate line
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Signal Plot')
plt.show()

# %% [markdown]
# ## 32 Layers

# %%
layer = []
for i in range(1,33):
    layer.append('Layer '+str(i))
